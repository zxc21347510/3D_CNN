# %%
#!/usr/bin/env python
# coding: utf-8

import tensorflow.keras 
from tensorflow.keras import optimizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import Input, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, concatenate
from tensorflow.keras.layers import Conv3D, MaxPooling3D, BatchNormalization, Flatten, Dropout
from tensorflow.keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint
import numpy as np
import matplotlib.pyplot as plt
import shutil as shutil
import os as os
import nibabel as nib
import tensorflow
import math

# %%
def curve(model, path):
    acc_fig_path = path + "/acc"
    loss_fig_path = path + "/loss"
    plt.plot(model.history['accuracy'])
    plt.plot(model.history['val_accuracy'])
    plt.title('model_accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig(acc_fig_path)
    plt.close()
    plt.plot(model.history['loss'])
    plt.plot(model.history['val_loss'])
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'valid'], loc='upper left')
    plt.savefig(loss_fig_path)
    plt.close()

# %%
def txt(model, path):
    acc_file_path = path + "/acc.txt"
    loss_file_path = path + "/loss.txt"
    acc_txt = open(acc_file_path,'w')
    loss_txt = open(loss_file_path,'w')
    
    acc = model.history['accuracy']
    val_acc = model.history['val_accuracy']
    loss = model.history['loss']
    val_loss = model.history['val_loss']
    for i in range (len(his.history['accuracy'])):
        acc_string = "epoch " + str(i+1) + ": acc = " + str(acc[i]) + "\t val_acc = " + str(val_acc[i]) + "\n"
        loss_string = "epoch " + str(i+1) + ": loss = " + str(loss[i]) + "\t val_loss = " + str(val_loss[i]) + "\n"
        acc_txt.write(acc_string)
        loss_txt.write(loss_string)
            

    acc_txt.close()
    loss_txt.close()

# %%
def txt_eva(string, path):
    eva_file_path = path + "/eva.txt"
    eva_txt = open(eva_file_path,'w')
    eva_txt.write(string)
    
    eva_txt.close()

# %%
def Alexnet5(width, height, depth, channel, num_classes):
    
    input_T1 = Input(shape=(width, height, depth, channel), name='input_T1')
    T1 = Conv3D(kernel_size=(5, 5, 5),filters=50,
                strides=(1,1,1))(input_T1)  
    T1 = Conv3D(kernel_size=(5, 5, 5),filters=50,
                strides=(2,2,2))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=100,padding = 'same',
                strides=(1,1,1))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=250,padding = 'same',
                strides=(2,2,2))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=400,padding = 'same',
                strides=(1,1,1))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=550,padding = 'same',
                strides=(2,2,2))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=700,padding = 'same',
                strides=(1,1,1))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=850,padding = 'same',
                strides=(2,2,2))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=1000,padding = 'same',
                strides=(1,1,1))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=1150,padding = 'same',
                strides=(2,2,2))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=1300,padding = 'same',
                strides=(1,1,1))(T1)
    T1 = Conv3D(kernel_size=(3, 3, 3),filters=1600,padding = 'same',
                strides=(2,2,2))(T1)
    
    x = Flatten()(T1)
     
#   要新增 activation 以及 fcn
    x = Activation('relu')(x)
    x = Dense(1000, activation='relu')(x)
    x = Dense(100, activation='relu')(x)
              
    output = Dense(num_classes, activation='softmax', name='output')(x)

    model = Model(inputs=[input_T1], outputs=[output])
    optimizer = tensorflow.keras.optimizers.SGD(learning_rate=0.0001)

    model.compile(
        optimizer=optimizer,
        loss=tensorflow.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=[tensorflow.keras.metrics.SparseCategoricalAccuracy(name="accuracy")],
    return model

# %%
def nifti_file_read(path, target_size):
    try:
        data = nib.load(path)
        data = data.get_fdata()
        data = (data-data.min())/ (data.max()-data.min()) *255
        data = data[:,:,:,np.newaxis]
    except Exception as e:
        print(e)
    else:
        x = np.expand_dims(np.array(data), axis=0)
        return x

# %%
def generator_four_img(path1, batch_size, class_array, target_size):
    
    # make data path list
    # make dir path list
    data_path_list = []
    for class_index in class_array :
        tmp_path = os.path.join(path1,class_index)
        data_path_list.append(tmp_path) 
        
    # make nii file path list
    nii_path = []
    for index in data_path_list:
        tmp_nii_path = os.listdir(index)
        for i in tmp_nii_path:
            tmp_path = os.path.join(index, i)
            nii_path.append(tmp_path)
            
#   make nii label
    nii_labels = []
    for path in nii_path:
        for index in range (len(class_array)):
            if ( "/" + class_array[index] + "/") in path:
                nii_labels.append(index)
                
    nii_labels_dict = {}
    for i in range (len(nii_path)):
        nii_labels_dict.setdefault(nii_path[i], nii_labels[i]) 
        
    steps = math.ceil(len(nii_path) / batch_size)    # 确定每轮有多少个batch
    print("Found %s images."%len(nii_path))
    while True:
        np.random.shuffle(nii_path)
        for i in range(steps):
            nii_batch_list = nii_path[i * batch_size : i * batch_size + batch_size]
            label_batch_list = []
            for label in nii_batch_list:
                label_batch_list.append(nii_labels_dict[label])
            
            x = [nifti_file_read(file, target_size) for file in nii_batch_list]
            batch_x = np.concatenate([array for array in x])
            
            # label 轉成 one hot
            y = [labels for labels in label_batch_list]
            y = np.expand_dims(np.array(y), axis=0)
            batch_y = np.concatenate([array for array in y]) 
            
            yield batch_x, batch_y

# %%
num_classes = 2
model = Alexnet5(181,217,181,1,num_classes)
model.summary()
class_array = ['AD', 'NC']


steps_per_epoch = 900
validation_steps = 100
test_steps = 66

num_epochs = 50
batch_size = 2

path1 = "/workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/train"
path5 = "/workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/valid"
path_test = "/workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test" 

path = "/workspace/YL/ADNC/3D-CNN_paper/result_10fold/data_range_-40~85_random_arc1_SGD_fold4"

if not os.path.isdir(path):
    os.mkdir(path)
else:
    shutil.rmtree(path)
    os.mkdir(path)   

best_model_path = path + "/best_model_ADNC.h5"
model_path = path + "/model_ADNC.h5"

train_flow = generator_four_img(path1, batch_size, class_array, (181,217,181))
valid_flow = generator_four_img(path5, batch_size, class_array, (181,217,181))
test_flow = generator_four_img(path_test, batch_size, class_array, (181,217,181))

stop = tensorflow.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=8, verbose=1, mode='auto', restore_best_weights=False)
best_model = ModelCheckpoint(best_model_path, monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
callbacks_list = [stop, best_model]

his = model.fit_generator(train_flow,
                steps_per_epoch=steps_per_epoch,
                epochs=num_epochs,
                verbose=1,
                callbacks=callbacks_list,
                validation_data=valid_flow,
                validation_steps=validation_steps)

curve(his, path)
txt(his, path)
model.save(model_path)
# Out:
# Model: "functional_1"
#
# _________________________________________________________________
#
# Layer (type)                 Output Shape              Param #
#
# =================================================================
#
# input_T1 (InputLayer)        [(None, 181, 217, 181, 1) 0
#
# _________________________________________________________________
#
# conv3d (Conv3D)              (None, 177, 213, 177, 50) 6300
#
# _________________________________________________________________
#
# conv3d_1 (Conv3D)            (None, 87, 105, 87, 50)   312550
#
# _________________________________________________________________
#
# conv3d_2 (Conv3D)            (None, 87, 105, 87, 100)  135100
#
# _________________________________________________________________
#
# conv3d_3 (Conv3D)            (None, 44, 53, 44, 267)   721167
#
# _________________________________________________________________
#
# conv3d_4 (Conv3D)            (None, 44, 53, 44, 434)   3129140
#
# _________________________________________________________________
#
# conv3d_5 (Conv3D)            (None, 22, 27, 22, 601)   7043119
#
# _________________________________________________________________
#
# conv3d_6 (Conv3D)            (None, 22, 27, 22, 768)   12463104
#
# _________________________________________________________________
#
# conv3d_7 (Conv3D)            (None, 11, 14, 11, 935)   19389095
#
# _________________________________________________________________
#
# conv3d_8 (Conv3D)            (None, 11, 14, 11, 1102)  27821092
#
# _________________________________________________________________
#
# conv3d_9 (Conv3D)            (None, 6, 7, 6, 1268)     37729340
#
# _________________________________________________________________
#
# conv3d_10 (Conv3D)           (None, 6, 7, 6, 1434)     49095858
#
# _________________________________________________________________
#
# conv3d_11 (Conv3D)           (None, 3, 4, 3, 1600)     61950400
#
# _________________________________________________________________
#
# flatten (Flatten)            (None, 57600)             0
#
# _________________________________________________________________
#
# activation (Activation)      (None, 57600)             0
#
# _________________________________________________________________
#
# dense (Dense)                (None, 1000)              57601000
#
# _________________________________________________________________
#
# dense_1 (Dense)              (None, 100)               100100
#
# _________________________________________________________________
#
# output (Dense)               (None, 2)                 202
#
# =================================================================
#
# Total params: 277,497,567
#
# Trainable params: 277,497,567
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# WARNING:tensorflow:From <ipython-input-8-b66376eb304b>:60: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
#
# Instructions for updating:
#
# Please use Model.fit, which supports generators.
#
# Found 1800 images.
#
# Epoch 1/50
#
#   2/900 [..............................] - ETA: 13:55 - loss: 8.8280 - accuracy: 0.0000e+00WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.5380s vs `on_train_batch_end` time: 1.3233s). Check your callbacks.
#
# 900/900 [==============================] - ETA: 0s - loss: 0.6555 - accuracy: 0.6789Found 200 images.
#
#
#
# Epoch 00001: val_accuracy improved from -inf to 0.78000, saving model to /workspace/YL/ADNC/3D-CNN_paper/result_10fold/data_range_-40~85_random_arc2_SGD_fold4/best_model_ADNC.h5
#
# 900/900 [==============================] - 1833s 2s/step - loss: 0.6555 - accuracy: 0.6789 - val_loss: 0.5246 - val_accuracy: 0.7800
#
# Epoch 2/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8528
#
# Epoch 00002: val_accuracy improved from 0.78000 to 0.84500, saving model to /workspace/YL/ADNC/3D-CNN_paper/result_10fold/data_range_-40~85_random_arc2_SGD_fold4/best_model_ADNC.h5
#
# 900/900 [==============================] - 1851s 2s/step - loss: 0.3754 - accuracy: 0.8528 - val_loss: 0.3861 - val_accuracy: 0.8450
#
# Epoch 3/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9639
#
# Epoch 00003: val_accuracy improved from 0.84500 to 0.88000, saving model to /workspace/YL/ADNC/3D-CNN_paper/result_10fold/data_range_-40~85_random_arc2_SGD_fold4/best_model_ADNC.h5
#
# 900/900 [==============================] - 1847s 2s/step - loss: 0.1358 - accuracy: 0.9639 - val_loss: 0.2807 - val_accuracy: 0.8800
#
# Epoch 4/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9978
#
# Epoch 00004: val_accuracy did not improve from 0.88000
#
# 900/900 [==============================] - 1841s 2s/step - loss: 0.0358 - accuracy: 0.9978 - val_loss: 0.2702 - val_accuracy: 0.8800
#
# Epoch 5/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
#
# Epoch 00005: val_accuracy did not improve from 0.88000
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.2529 - val_accuracy: 0.8800
#
# Epoch 6/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
#
# Epoch 00006: val_accuracy improved from 0.88000 to 0.90500, saving model to /workspace/YL/ADNC/3D-CNN_paper/result_10fold/data_range_-40~85_random_arc2_SGD_fold4/best_model_ADNC.h5
#
# 900/900 [==============================] - 1848s 2s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9050
#
# Epoch 7/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
#
# Epoch 00007: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2754 - val_accuracy: 0.8800
#
# Epoch 8/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
#
# Epoch 00008: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2196 - val_accuracy: 0.9050
#
# Epoch 9/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
#
# Epoch 00009: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.8950
#
# Epoch 10/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00010: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3002 - val_accuracy: 0.8800
#
# Epoch 11/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00011: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2337 - val_accuracy: 0.9000
#
# Epoch 12/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00012: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1840s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.8900
#
# Epoch 13/50
#
# 900/900 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00013: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1838s 2s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9000
#
# Epoch 14/50
#
# 900/900 [==============================] - ETA: 0s - loss: 9.3646e-04 - accuracy: 1.0000
#
# Epoch 00014: val_accuracy did not improve from 0.90500
#
# 900/900 [==============================] - 1838s 2s/step - loss: 9.3646e-04 - accuracy: 1.0000 - val_loss: 0.3044 - val_accuracy: 0.8800
#
# Epoch 00014: early stopping

# %%
tensorflow.keras.models.load_model(model_path)
_, accuracy = model.evaluate(test_flow,
                             steps=test_steps,
                             verbose=1,)

print(f"Test accuracy: {round(accuracy * 100, 2)}%")

string = f"Test accuracy: {round(accuracy * 100, 2)}%" + "\n"
txt_eva(string, path)
# Out:
# Found 132 images.
#
# 66/66 [==============================] - 42s 632ms/step - loss: 0.1597 - accuracy: 0.9394
#
# Test accuracy: 93.94%

# %%
from tensorflow.keras.models import load_model

import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import os

from scipy import ndimage

label = class_array
class_num = 2
test_path = []

original_path = path_test
result_path = path + "/result.txt"

for i in range (1):
    for j in range (class_num):
        walk_path = original_path + "/" + label[j]
        test_path.append(walk_path)

model = tensorflow.keras.models.load_model(model_path)
record = open(result_path,'w')

for i in range (class_num):
    
    AD = 0
    LMCI = 0
    EMCI = 0
    NC = 0

    result = ""
    
    
    if i == 0:
        result = result + "AD: \n"
    elif i ==1:
        result = result + "NC: \n"
    data_list1 = os.listdir(test_path[class_num*0+i]) 

    data_list1.sort(key=lambda x:str(x[:-7]))
    
    for j in range (len(data_list1)):
        test1 = test_path[class_num*0+i] + "/" + data_list1[j]
        print(test1)
        
        data = nifti_file_read(test1, (181,217,181))
        preds = model.predict([data])
        
        if preds.argmax() == 0:
            AD = AD + 1
            result = result + (data_list1[j][:-7]) + "\tAD" + "\n"
        elif preds.argmax() == 1:
            NC = NC + 1
            result = result + (data_list1[j][:-7]) + "\tNC" + "\n"

    result = result + "AD: " + str(AD) + " NC: " + str(NC) + "\n"
    record.write(result)
            
record.close()
# Out:
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w002_S_0816-MPRAGE-2006-09-29_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w003_S_4152-Sag_IR-SPGR-2011-08-30_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w003_S_5187-Sag_IR-SPGR-2013-09-13_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w005_S_5119-Sag_IR-FSPGR-2014-04-22_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w007_S_4568-Sag_IR-SPGR-2012-09-17_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w009_S_5037-MPRAGE-2014-02-11_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w011_S_4912-MPRAGE-2012-11-16_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w016_S_4009-Sag_IR-SPGR-2011-06-18_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w016_S_4887-Sag_IR-SPGR-2013-04-30_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w023_S_0139-MPRAGE-2008-03-04_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w023_S_5241-MPRAGE-2013-08-09_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w027_S_1385-MPRAGE-2009-03-12_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w027_S_4964-Sag_IR-FSPGR-2013-10-08_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w032_S_4755-MPRAGE-2012-07-02_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w036_S_4894-MPRAGE-2012-11-09_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w037_S_4770-MPRAGE-2012-10-17_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w052_S_5062-Sag_IR-FSPGR-2014-04-22_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w067_S_1185-MPRAGE-2007-08-07_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w068_S_4859-MPRAGE-2012-12-10_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w070_S_4719-MPRAGE-2012-05-21_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w082_S_5029-MPRAGE-2013-03-28_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w094_S_4089-Sag_IR-SPGR-2012-08-15_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w098_S_4215-Sag_IR-SPGR-2011-09-12_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w098_S_4215-Sag_IR-SPGR-2012-10-30_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w116_S_4195-MPRAGE-2011-08-31_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w116_S_4338-MPRAGE-2011-11-02_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w116_S_4625-MPRAGE-2012-03-29_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w123_S_4526-MPRAGE-2012-02-09_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w126_S_0606-MP-RAGE-2006-08-14_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w126_S_4686-Sag_IR-SPGR-2012-08-01_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w127_S_0844-MP-RAGE-2007-05-16_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w127_S_4940-Sag_IR-FSPGR-2013-03-25_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w127_S_4992-Sag_IR-FSPGR-2013-04-25_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w127_S_5028-Sag_IR-SPGR-2012-11-14_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w127_S_5067-Sag_IR-FSPGR-2013-02-04_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w127_S_5067-Sag_IR-FSPGR-2014-01-28_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w128_S_4774-MPRAGE-2012-06-21_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w130_S_4730-MPRAGE-2013-06-12_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w131_S_0457-MP-RAGE-2006-06-05_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w135_S_4657-MPRAGE-2012-07-12_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w135_S_4863-MPRAGE-2013-02-20_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w135_S_5015-MPRAGE-2013-11-25_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w137_S_4211-MPRAGE-2012-04-18_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/AD/w153_S_4172-MPRAGE-2013-09-25_AD.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w002_S_1261-MPRAGE-2007-02-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w002_S_1280-MPRAGE-2007-10-10_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w002_S_4270-MPRAGE-2012-05-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w003_S_4119-Sag_IR-SPGR-2011-08-09_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w003_S_4288-Sag_IR-SPGR-2012-11-01_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w003_S_4350-Sag_IR-SPGR-2012-06-06_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w003_S_4555-Sag_IR-SPGR-2012-11-07_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w003_S_4644-Sag_IR-SPGR-2013-05-24_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w003_S_4872-Sag_IR-SPGR-2013-04-18_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w005_S_0553-MP-RAGE-2007-01-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w005_S_0553-MP-RAGE-2009-09-15_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w006_S_4449-MPRAGE-2012-01-19_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w006_S_4485-MPRAGE-2014-03-14_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w007_S_4387-Sag_IR-SPGR-2011-12-05_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w007_S_4488-Sag_IR-SPGR-2012-04-30_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w007_S_4516-Sag_IR-SPGR-2012-08-27_NC.nii.gz
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w007_S_4620-Sag_IR-SPGR-2012-07-05_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w007_S_4637-Sag_IR-SPGR-2012-10-29_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w009_S_0751-MPRAGE-2014-09-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w009_S_4337-MPRAGE-2011-11-07_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w009_S_4388-MPRAGE-2016-02-23_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w009_S_4612-MPRAGE-2014-04-30_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w010_S_4442-MPRAGE-2013-05-10_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w011_S_0023-MPRAGE-2011-12-20_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w011_S_4075-MPRAGE-2011-12-14_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w011_S_4105-MPRAGE-2013-07-26_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w011_S_4120-MPRAGE-2011-10-10_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w011_S_4222-MPRAGE-2015-09-18_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w011_S_4278-MPRAGE-2015-11-02_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w013_S_4616-MPRAGE-2014-04-24_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w014_S_4093-MPRAGE-2012-01-12_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w014_S_4576-MPRAGE-2013-04-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w016_S_4097-Sag_IR-SPGR-2011-07-05_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w016_S_4121-Sag_IR-SPGR-2012-08-13_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w016_S_4951-Sag_IR-SPGR-2013-05-15_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w016_S_4952-Sag_IR-SPGR-2013-11-13_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w018_S_4257-MPRAGE-2012-07-31_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w018_S_4400-MPRAGE-2012-04-09_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w019_S_4835-MPRAGE-2013-01-15_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w020_S_1288-MPRAGE-2009-03-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w021_S_4276-Sag_IR-SPGR-2012-10-22_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w021_S_4421-Sag_IR-SPGR-2012-07-19_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w022_S_4173-MPRAGE-2012-03-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w022_S_4291-MPRAGE-2011-11-22_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w022_S_4291-MPRAGE-2016-02-19_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w022_S_4320-MPRAGE-2013-12-06_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w023_S_0926-MPRAGE-2006-10-16_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w023_S_1190-MPRAGE-2007-01-17_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w023_S_4020-MPRAGE-2013-06-10_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w023_S_4448-MPRAGE-2016-05-12_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w024_S_4158-MPRAGE-2015-09-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w029_S_4290-IR-SPGR-2012-12-06_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w029_S_4384-Sag_IR-FSPGR-2016-04-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w029_S_4652-IR-SPGR-2012-04-20_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w031_S_4496-MPRAGE-2012-02-03_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w032_S_0677-MPRAGE-2009-07-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w032_S_4429-MPRAGE-2011-12-22_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w033_S_1016-MPRAGE-2009-12-02_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w035_S_4082-MPRAGE-2015-11-03_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w036_S_4491-MPRAGE-2014-02-21_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w037_S_0454-MPRAGE-2013-01-14_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w041_S_4014-MPRAGE-2011-04-18_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w041_S_4041-MPRAGE-2013-05-13_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w041_S_4427-MPRAGE-2012-06-25_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w052_S_1251-MP-RAGE-2007-03-09_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w068_S_4174-MPRAGE-2011-08-19_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w070_S_4856-MPRAGE-2013-02-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w073_S_0089-MPRAGE-2012-10-09_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w073_S_4393-MPRAGE-2013-12-09_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w073_S_4762-MPRAGE-2012-09-05_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w082_S_4090-MPRAGE-2012-01-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w082_S_4428-MPRAGE-2012-06-25_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w094_S_4649-Sag_IR-SPGR-2016-06-09_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w098_S_4050-Sag_IR-SPGR-2011-05-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w099_S_4086-MPRAGE-2012-02-01_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w116_S_1232-MPRAGE-2008-01-30_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w116_S_4092-MPRAGE-2015-07-20_NC.nii.gz
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w123_S_4362-MPRAGE-2011-11-28_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w127_S_4148-Sag_IR-FSPGR-2013-08-15_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w127_S_4645-Sag_IR-SPGR-2012-04-04_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w128_S_4607-MPRAGE-2012-06-28_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w129_S_4396-IR-SPGR-2012-02-15_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w131_S_0123-Sag_IR-SPGR-2015-03-03_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w135_S_4566-MPRAGE-2013-03-27_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w137_S_0301-MPRAGE-2012-04-20_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w137_S_4482-MPRAGE-2016-03-18_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w153_S_4372-MPRAGE-2013-12-11_NC.nii.gz
#
# /workspace/YL/ADNC/3D-CNN_paper/ADNI_T1_data_VBM_fill_with_0_range_-40~85_random_fold4/test/NC/w941_S_4100-MPRAGE-2011-10-03_NC.nii.gz
